# %%
import pandas as pd

# %%
data = pd.read_csv("../data/TEST_F_VALUES.csv")

# %%
data
# Out:
#       Unnamed: 0   FIPS    STATE  EP_POV150  EP_MINRTY  E_UNEMP  \
# 0              1   1001  Alabama       22.9       26.0      736
# 1              2   1003  Alabama       16.9       17.1     4027
# 2              3   1005  Alabama       40.6       54.7      649
# 3              4   1007  Alabama       27.6       25.6      667
# 4              5   1009  Alabama       23.8       13.3     1253
# ...          ...    ...      ...        ...        ...      ...
# 2589        3138  56035  Wyoming       12.8       11.3      269
# 2590        3139  56037  Wyoming       18.0       21.2     1437
# 2591        3140  56039  Wyoming       11.9       18.8      280
# 2592        3141  56041  Wyoming       18.2       12.7      453
# 2593        3142  56043  Wyoming       19.2       18.2      170
#
#       Predicted.f.full_lm  Predicted.f.E_UNEMP_lm
# 0                0.083209                0.074249
# 1                0.115612                0.121390
# ...

# %%
data2 = data[["FIPS", "Predicted.f.full_lm"]]

# %%
print(data[data["FIPS"] == 48201 ])
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, FIPS, STATE, EP_POV150, EP_MINRTY, E_UNEMP, Predicted.f.full_lm, Predicted.f.E_UNEMP_lm]
# Index: []

# %%
data2
# Out:
#        FIPS  Predicted.f.full_lm
# 0      1001             0.083209
# 1      1003             0.115612
# 2      1005             0.124556
# 3      1007             0.086685
# 4      1009             0.080509
# ...     ...                  ...
# 2589  56035             0.053810
# 2590  56037             0.083940
# 2591  56039             0.059462
# 2592  56041             0.063083
# 2593  56043             0.064839
#
# [2594 rows x 2 columns]

# %%
data2.rename(columns={'Predicted.f.full_lm': 'F-VALUES'}, inplace=True)
# Out:
# C:\Users\kushd\AppData\Local\Temp\ipykernel_13920\2885156297.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.rename(columns={'Predicted.f.full_lm': 'F-VALUES'}, inplace=True)

# %%
data2
# Out:
#        FIPS  F-VALUES
# 0      1001  0.083209
# 1      1003  0.115612
# 2      1005  0.124556
# 3      1007  0.086685
# 4      1009  0.080509
# ...     ...       ...
# 2589  56035  0.053810
# 2590  56037  0.083940
# 2591  56039  0.059462
# 2592  56041  0.063083
# 2593  56043  0.064839
#
# [2594 rows x 2 columns]

# %%
data2["F-VALUES"].min()
# Out:
# 0.027344667871256

# %%
data2["F-VALUES"].max()
# Out:
# 2.81733955546034

# %%
data2.to_csv(../data/predicted_complete.
