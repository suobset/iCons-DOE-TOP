# %%
import glob
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib.collections import PatchCollection
from matplotlib.colors import rgb2hex
from PIL import ImageColor
import geopandas as gpd
from generativepy.color import Color
import contextily as cx

### percentile bounds defining upper boundaries of color classes
percentile_bounds = [25, 50, 75, 100]

# %%
# !pip3 install generativepy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import json
import shapefile as SF
import pandas as pd
import warnings
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')
#with open('countiesfips.json') as f:
#    d = json.load(f)
#print(len(d))    
df = pd.read_csv("updated EAGLE-I/eaglei_outages_2020.csv")
df = df.groupby('fips_code').mean()
df.reset_index(inplace = True, drop = False)
#print(df)
df2 = pd.read_csv("data/svi_interactive_map2020.csv")
df2 = df2.drop(columns = ['GEO LEVEL', 'GEO COMPARISON','YEAR', 'GEO UNIT', 'ST', 'STATE','ST_ABBR', 'STCNTY', 'COUNTY'])
df2 = df2.rename(columns = {'FIPS': 'fips_code'})
display(pd.merge(df, df2).corr()['customers_out'].sort_values())
display(pd.merge(df, df2).corr()['customers_out']['RPL_THEMES'])

plt.matshow(pd.merge(df, df2).corr())
plt.colorbar(label="Correlation", orientation="horizontal")
plt.show()
# Out:
# MP_HBURD        -0.096404
# MP_MUNIT        -0.086988
# MP_UNINSUR      -0.078245
# MP_POV150       -0.077113
# MP_SNGPNT       -0.076602
#                    ...
# M_DISABL         0.203876
# M_POV150         0.206200
# M_MOBILE         0.217525
# customers_out    1.000000
# F_Total               NaN
# Name: customers_out, Length: 152, dtype: float64
# 0.11371153547780505

# %%
# !pip3 install numpy==1.23
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 11.7 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
# ...
