# %% [markdown]
# # MouseBot
# ### by kush
#
# A bot that controls your mouse on a new Chromium Window.
#
# Coded to facilitate data scraping in an easy way.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# Set the URL of the webpage you want to interact with
url = "https://gem.anl.gov/tool"  # Replace with your target URL

# Set the path to your web driver (e.g., ChromeDriver)
driver_path = "/media/suobset/Kush testBench/GitHub/iCons-DOE-TOP/chromedriver"  # Download from https://sites.google.com/chromium.org/driver/

# Initialize the web driver
driver = webdriver.Chrome()

# Navigate to the webpage
driver.get(url)

# Define a function to perform the repetitive actions
def perform_actions():
    try:
        # Locate and click on the dataset element (you may need to inspect the webpage to get the appropriate selector)
        dataset_element = driver.find_element(By.CSS_SELECTOR, "div.module_button[phx-click='catalog-toggle']")
        dataset_element.click()

        start_component = 3
        end_component = 1000
        # Click Model Input and Model Output
        time.sleep(5)
        # Declare element_to_click outside of the loop
        element_to_click = None

        # Iterate through the range and click on elements
        for component_id in range(start_component, end_component + 1):
            # Construct the CSS selector based on the component_id
            selector = f"tr[data-phx-component='{component_id}']"

            try:
                # Find the element by its CSS selector
                element_to_click = driver.find_element(By.CSS_SELECTOR, selector)

                # Click the element
                element_to_click.click()

            except Exception as e:
                print(f"Error clicking element with data-phx-component={component_id}: {str(e)}")

            try:
                if True:
                    print("HERE1")
                    # Find and click the "Download" button within the element
                    download_button = driver.find_element(By.XPATH, ".//button[contains(., 'Download')]")
                    download_button.click()
                    time.sleep(1)
            except Exception as e:
                print(f"Error clicking Download: {str(e)}")

        time.sleep(1)  # Wait for 1 second (adjust as needed)

    except Exception as e:
        print("An error occurred:", str(e))

# # Define the number of repetitions
# num_repetitions = 1  # Change as needed

# # Perform the actions repeatedly
# for _ in range(num_repetitions):
#     perform_actions()

perform_actions()
# To facilitate downhloading. If all downloaded, stop this cell manually (do not just exit browser)
time.sleep(1000)
# Close the web driver
driver.quit()
# Out:
# HERE1
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# HERE1
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# HERE1
# Error clicking element with data-phx-component=202: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='202']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=203: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='203']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=204: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='204']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=205: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='205']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=206: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='206']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=207: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='207']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=208: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='208']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=209: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='209']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=210: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='210']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=211: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='211']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=212: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='212']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=213: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='213']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=214: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='214']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=215: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='215']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=216: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='216']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=217: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='217']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=218: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='218']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=219: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='219']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=220: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='220']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=221: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='221']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=222: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='222']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=223: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='223']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=224: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='224']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=225: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='225']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=226: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='226']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=227: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='227']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=228: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='228']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=229: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='229']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=230: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='230']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=231: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='231']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=232: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='232']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=233: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='233']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=234: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='234']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=235: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='235']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=236: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='236']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=237: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='237']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=238: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='238']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=239: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='239']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=240: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='240']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=241: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='241']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# ...
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=489: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='489']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=490: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='490']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=491: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='491']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=492: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='492']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=493: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='493']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=494: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='494']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=495: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='495']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=496: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='496']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=497: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='497']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=498: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='498']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=499: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='499']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=500: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='500']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=501: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='501']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=502: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='502']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=503: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='503']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# Error clicking element with data-phx-component=504: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='504']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x560fffb306b3 <unknown>
# #1 0x560fff8061e7 <unknown>
# #2 0x560fff84d566 <unknown>
# #3 0x560fff84d651 <unknown>
# #4 0x560fff88aa74 <unknown>
# #5 0x560fff86f0ed <unknown>
# #6 0x560fff888322 <unknown>
# #7 0x560fff86ee93 <unknown>
# #8 0x560fff841934 <unknown>
# #9 0x560fff84271e <unknown>
# #10 0x560fffaf5cb8 <unknown>
# #11 0x560fffaf9bf0 <unknown>
# #12 0x560fffb0419c <unknown>
# #13 0x560fffafa808 <unknown>
# #14 0x560fffac727f <unknown>
# #15 0x560fffb1ee88 <unknown>
# #16 0x560fffb1f059 <unknown>
# #17 0x560fffb2f843 <unknown>
# #18 0x7f57e5a94b43 <unknown>
#
# HERE1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 69
#      60         print("An error occurred:", str(e))
#      62 # # Define the number of repetitions
#      63 # num_repetitions = 1  # Change as needed
#      64
#      65 # # Perform the actions repeatedly
#      66 # for _ in range(num_repetitions):
#      67 #     perform_actions()
# ---> 69 perform_actions()
#      70 # To facilitate downhloading. If all downloaded, stop this cell manually (do not just exit browser)
#      71 time.sleep(1000)
#
# Cell In[12], line 53, in perform_actions()
#      51         download_button = driver.find_element(By.XPATH, ".//button[contains(., 'Download')]")
#      52         download_button.click()
# ---> 53         time.sleep(1)
#      54 except Exception as e:
#      55     print(f"Error clicking Download: {str(e)}")
#
# KeyboardInterrupt:

# %%
# !pip install --upgrade selenium beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: selenium in /home/suobset/.local/lib/python3.10/site-packages (4.13.0)
# Requirement already satisfied: beautifulsoup4 in /home/suobset/.local/lib/python3.10/site-packages (4.12.2)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/lib/python3/dist-packages (from selenium) (1.26.5)
# Requirement already satisfied: trio~=0.17 in /home/suobset/.local/lib/python3.10/site-packages (from selenium) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in /home/suobset/.local/lib/python3.10/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /home/suobset/.local/lib/python3.10/site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: soupsieve>1.2 in /home/suobset/.local/lib/python3.10/site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: attrs>=20.1.0 in /home/suobset/.local/lib/python3.10/site-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in /home/suobset/.local/lib/python3.10/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: outcome in /home/suobset/.local/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in /home/suobset/.local/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /home/suobset/.local/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.1.3)
# Requirement already satisfied: wsproto>=0.14 in /home/suobset/.local/lib/python3.10/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /home/suobset/.local/lib/python3.10/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /home/suobset/.local/lib/python3.10/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
