# %% [markdown]
# # MouseBot
# ### by kush
#
# A bot that controls your mouse on a new Chromium Window.
#
# Coded to facilitate data scraping in an easy way.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# Set the URL of the webpage you want to interact with
url = "https://gem.anl.gov/tool"  # Replace with your target URL

# Set the path to your web driver (e.g., ChromeDriver)
driver_path = "/media/suobset/Kush testBench/GitHub/iCons-DOE-TOP/chromedriver"  # Download from https://sites.google.com/chromium.org/driver/

# Initialize the web driver
driver = webdriver.Chrome()

# Navigate to the webpage
driver.get(url)

# Define a function to perform the repetitive actions
def perform_actions():
    try:
        # Locate and click on the dataset element (you may need to inspect the webpage to get the appropriate selector)
        dataset_element = driver.find_element(By.CSS_SELECTOR, "div.module_button[phx-click='catalog-toggle']")
        dataset_element.click()

        start_component = 3
        end_component = 201

        # Declare element_to_click outside of the loop
        element_to_click = None

        # Iterate through the range and click on elements
        for component_id in range(start_component, end_component + 1):
            # Construct the CSS selector based on the component_id
            selector = f"tr[data-phx-component='{component_id}']"

            try:
                # Find the element by its CSS selector
                element_to_click = driver.find_element(By.CSS_SELECTOR, selector)

                # Click the element
                element_to_click.click()

            except Exception as e:
                print(f"Error clicking element with data-phx-component={component_id}: {str(e)}")

            try:
                if element_to_click is not None:
                    # Find and click the "Download" button within the element
                    download_button = element_to_click.find_element(By.XPATH, ".//button[contains(., 'Download')]")
                    download_button.click()
                    time.sleep(5)
            except Exception as e:
                print(f"Error clicking Download: {str(e)}")

        time.sleep(1)  # Wait for 1 second (adjust as needed)

    except Exception as e:
        print("An error occurred:", str(e))

# # Define the number of repetitions
# num_repetitions = 1  # Change as needed

# # Perform the actions repeatedly
# for _ in range(num_repetitions):
#     perform_actions()

perform_actions()

# Close the web driver
driver.quit()
# Out:
# Error clicking element with data-phx-component=3: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='3']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x561186993a74 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x561186991322 <unknown>
# #7 0x561186977e93 <unknown>
# #8 0x56118694a934 <unknown>
# #9 0x56118694b71e <unknown>
# #10 0x561186bfecb8 <unknown>
# #11 0x561186c02bf0 <unknown>
# #12 0x561186c0d19c <unknown>
# #13 0x561186c03808 <unknown>
# #14 0x561186bd027f <unknown>
# #15 0x561186c27e88 <unknown>
# #16 0x561186c28059 <unknown>
# #17 0x561186c38843 <unknown>
# #18 0x7fe912694b43 <unknown>
#
# Error clicking element with data-phx-component=4: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='4']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x561186993a74 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x561186991322 <unknown>
# #7 0x561186977e93 <unknown>
# #8 0x56118694a934 <unknown>
# #9 0x56118694b71e <unknown>
# #10 0x561186bfecb8 <unknown>
# #11 0x561186c02bf0 <unknown>
# #12 0x561186c0d19c <unknown>
# #13 0x561186c03808 <unknown>
# #14 0x561186bd027f <unknown>
# #15 0x561186c27e88 <unknown>
# #16 0x561186c28059 <unknown>
# #17 0x561186c38843 <unknown>
# #18 0x7fe912694b43 <unknown>
#
# Error clicking element with data-phx-component=5: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='5']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x561186993a74 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x561186991322 <unknown>
# #7 0x561186977e93 <unknown>
# #8 0x56118694a934 <unknown>
# #9 0x56118694b71e <unknown>
# #10 0x561186bfecb8 <unknown>
# #11 0x561186c02bf0 <unknown>
# #12 0x561186c0d19c <unknown>
# #13 0x561186c03808 <unknown>
# #14 0x561186bd027f <unknown>
# #15 0x561186c27e88 <unknown>
# #16 0x561186c28059 <unknown>
# #17 0x561186c38843 <unknown>
# #18 0x7fe912694b43 <unknown>
#
# Error clicking element with data-phx-component=6: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='6']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x561186993a74 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x561186991322 <unknown>
# #7 0x561186977e93 <unknown>
# #8 0x56118694a934 <unknown>
# #9 0x56118694b71e <unknown>
# #10 0x561186bfecb8 <unknown>
# #11 0x561186c02bf0 <unknown>
# #12 0x561186c0d19c <unknown>
# #13 0x561186c03808 <unknown>
# #14 0x561186bd027f <unknown>
# #15 0x561186c27e88 <unknown>
# #16 0x561186c28059 <unknown>
# #17 0x561186c38843 <unknown>
# #18 0x7fe912694b43 <unknown>
#
# Error clicking element with data-phx-component=7: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='7']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x561186993a74 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x561186991322 <unknown>
# #7 0x561186977e93 <unknown>
# #8 0x56118694a934 <unknown>
# #9 0x56118694b71e <unknown>
# #10 0x561186bfecb8 <unknown>
# #11 0x561186c02bf0 <unknown>
# #12 0x561186c0d19c <unknown>
# #13 0x561186c03808 <unknown>
# #14 0x561186bd027f <unknown>
# #15 0x561186c27e88 <unknown>
# #16 0x561186c28059 <unknown>
# #17 0x561186c38843 <unknown>
# #18 0x7fe912694b43 <unknown>
#
# Error clicking element with data-phx-component=8: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='8']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x561186993a74 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x561186991322 <unknown>
# #7 0x561186977e93 <unknown>
# #8 0x56118694a934 <unknown>
# #9 0x56118694b71e <unknown>
# #10 0x561186bfecb8 <unknown>
# #11 0x561186c02bf0 <unknown>
# #12 0x561186c0d19c <unknown>
# #13 0x561186c03808 <unknown>
# #14 0x561186bd027f <unknown>
# #15 0x561186c27e88 <unknown>
# #16 0x561186c28059 <unknown>
# #17 0x561186c38843 <unknown>
# #18 0x7fe912694b43 <unknown>
#
# Error clicking element with data-phx-component=9: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tr[data-phx-component='9']"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x561186993a74 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x561186991322 <unknown>
# #7 0x561186977e93 <unknown>
# #8 0x56118694a934 <unknown>
# #9 0x56118694b71e <unknown>
# #10 0x561186bfecb8 <unknown>
# #11 0x561186c02bf0 <unknown>
# #12 0x561186c0d19c <unknown>
# #13 0x561186c03808 <unknown>
# #14 0x561186bd027f <unknown>
# #15 0x561186c27e88 <unknown>
# #16 0x561186c28059 <unknown>
# #17 0x561186c38843 <unknown>
# #18 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x561186c396b3 <unknown>
# #1 0x56118690f1e7 <unknown>
# #2 0x561186956566 <unknown>
# #3 0x561186956651 <unknown>
# #4 0x56118694c046 <unknown>
# #5 0x5611869780ed <unknown>
# #6 0x56118694bf16 <unknown>
# #7 0x56118697828e <unknown>
# #8 0x561186991322 <unknown>
# #9 0x561186977e93 <unknown>
# #10 0x56118694a934 <unknown>
# #11 0x56118694b71e <unknown>
# #12 0x561186bfecb8 <unknown>
# #13 0x561186c02bf0 <unknown>
# #14 0x561186c0d19c <unknown>
# #15 0x561186c03808 <unknown>
# #16 0x561186bd027f <unknown>
# #17 0x561186c27e88 <unknown>
# #18 0x561186c28059 <unknown>
# #19 0x561186c38843 <unknown>
# #20 0x7fe912694b43 <unknown>
#
# Error clicking Download: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//button[contains(., 'Download')]"}
# ...
# Error clicking element with data-phx-component=180: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70d8a0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70dcc0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=181: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f769060>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70d990>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=182: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70df00>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70d060>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=183: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70ea40>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f769450>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=184: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70f160>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70f3a0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=185: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70d570>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70d810>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=186: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f769840>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70e740>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=187: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70d900>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70d840>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=188: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70fc10>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f769d20>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=189: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70d000>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70cd60>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=190: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70d8a0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70ef50>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=191: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f76a200>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464ff29f60>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=192: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70e080>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70eda0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=193: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70dae0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70d9c0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=194: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464ff21ff0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70db40>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=195: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70d1b0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70f220>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=196: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70de10>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464ff2aad0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=197: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70e080>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70eb30>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=198: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70f3d0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70d660>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=199: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464ff23130>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70edd0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=200: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70d420>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70ef50>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking element with data-phx-component=201: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464f70ece0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error clicking Download: HTTPConnectionPool(host='localhost', port=57863): Max retries exceeded with url: /session/f2d97d741cd7abf169c1c3510864af47/element/8C5BC08DFFBBC204EB31095277D4CD70_element_559/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f464ff290c0>: Failed to establish a new connection: [Errno 111] Connection refused'))

# %%
# !pip install --upgrade selenium beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: selenium in /home/suobset/.local/lib/python3.10/site-packages (4.13.0)
# Requirement already satisfied: beautifulsoup4 in /home/suobset/.local/lib/python3.10/site-packages (4.12.2)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/lib/python3/dist-packages (from selenium) (1.26.5)
# Requirement already satisfied: trio~=0.17 in /home/suobset/.local/lib/python3.10/site-packages (from selenium) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in /home/suobset/.local/lib/python3.10/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /home/suobset/.local/lib/python3.10/site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: soupsieve>1.2 in /home/suobset/.local/lib/python3.10/site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: attrs>=20.1.0 in /home/suobset/.local/lib/python3.10/site-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in /home/suobset/.local/lib/python3.10/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: outcome in /home/suobset/.local/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in /home/suobset/.local/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /home/suobset/.local/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.1.3)
# Requirement already satisfied: wsproto>=0.14 in /home/suobset/.local/lib/python3.10/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /home/suobset/.local/lib/python3.10/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /home/suobset/.local/lib/python3.10/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
